# %%
import torch
from v1 import *
from torchvision import datasets, transforms


import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# Example usage with XOR data
input_size = 2  # XOR has two input features (0 or 1)
hidden_size = 4  # Hidden layers size
hidden_layers_number = 1 # Number of hidden layers
output_size = 1  # XOR has one output feature (0 or 1)
# Define XOR inputs and targets
data = torch.tensor([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=torch.float32)  # XOR inputs
targets = torch.tensor([[0], [1], [1], [0]], dtype=torch.float32)  # XOR targets

# Initialize the model and loss function
model = SimpleDFA(input_size, hidden_size, output_size, hidden_layers_number)
model.Init_weights()  # Initialize the weights

loss_fn = nn.MSELoss()

# Train the network using DFA and print XOR accuracy
train(model, data, targets, loss_fn, learning_rate=0.1, epochs=1000)
# Out:
# Epoch [0/1000], Loss: 0.4660068452358246
# Accuracy: 50.00%
# Epoch [100/1000], Loss: 0.13536852598190308
# Accuracy: 100.00%
# Epoch [200/1000], Loss: 0.034751150757074356
# Accuracy: 100.00%
# Epoch [300/1000], Loss: 0.0036188531666994095
# Accuracy: 100.00%
# Epoch [400/1000], Loss: 0.00038689636858180165
# Accuracy: 100.00%
# Epoch [500/1000], Loss: 4.2288473196094856e-05
# Accuracy: 100.00%
# Epoch [600/1000], Loss: 4.662786068365676e-06
# Accuracy: 100.00%
# Epoch [700/1000], Loss: 5.158836984264781e-07
# Accuracy: 100.00%
# Epoch [800/1000], Loss: 5.707672912080852e-08
# Accuracy: 100.00%
# Epoch [900/1000], Loss: 6.319797130061033e-09
# Accuracy: 100.00%

# %%
print("Data preparation")
# MNIST dataset setup
transform = transforms.Compose([transforms.ToTensor(), transforms.Lambda(lambda x: x.view(-1))])  # Flatten the images
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
# Flattened MNIST data (28x28 to 784x1)
data = torch.stack([x[0] for x in train_dataset], dim=0)  # Stacking the flattened images
targets = torch.tensor([x[1] for x in train_dataset], dtype=torch.long)  # MNIST targets are integers, so we use long dtype
print("Data preparation DONE")
# Out:
# Data preparation
# Data preparation DONE

# %%
input_size = 784  
hidden_size = 20  # Hidden layers size
hidden_layers_number = 3 # Number of hidden layers
output_size = 10  


# Initialize the model and loss function
model = SimpleDFA(input_size, hidden_size, output_size, hidden_layers_number)
model.Init_weights()  # Initialize the weights

loss_fn = nn.MSELoss()

# Train the network using DFA and print accuracy
train(model, data, targets, loss_fn, learning_rate=0.1, epochs=1000)
# Out:
# /home/leo/miniconda3/lib/python3.12/site-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([60000])) that is different to the input size (torch.Size([60000, 10])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 14
#      11 loss_fn = nn.MSELoss()
#      13 # Train the network using DFA and print accuracy
# ---> 14 train(model, data, targets, loss_fn, learning_rate=0.1, epochs=1000)
#
# File ~/Desktop/Free Project/v1/basic_training.py:20, in train(model, data, targets, loss_fn, learning_rate, epochs)
#      17     x = model.activation(layer(x))
#      18     hidden_activations.append(x)
# ---> 20 output, loss = model.forward_pass(data, targets, loss_fn)
#      22 # Apply DFA update step
#      23 dfa_update_step(model, Bs, output, targets, hidden_activations, data, learning_rate)
#
# File ~/Desktop/Free Project/v1/model.py:56, in SimpleDFA.forward_pass(self, Input, Target, loss_func)
#      52 def forward_pass(self,Input,Target,loss_func):
#      53
#      54     # Forward pass
#      55     Output = self.forward(Input)
# ---> 56     loss = loss_func(Output, Target)
#      57     return Output, loss
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/loss.py:608, in MSELoss.forward(self, input, target)
#     607 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 608     return F.mse_loss(input, target, reduction=self.reduction)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/functional.py:3791, in mse_loss(input, target, size_average, reduce, reduction)
#    3788 if size_average is not None or reduce is not None:
#    3789     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3791 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3792 return torch._C._nn.mse_loss(
#    3793     expanded_input, expanded_target, _Reduction.get_enum(reduction)
#    3794 )
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/functional.py:76, in broadcast_tensors(*tensors)
#      74 if has_torch_function(tensors):
#      75     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 76 return _VF.broadcast_tensors(tensors)
#
# RuntimeError: The size of tensor a (10) must match the size of tensor b (60000) at non-singleton dimension 1
